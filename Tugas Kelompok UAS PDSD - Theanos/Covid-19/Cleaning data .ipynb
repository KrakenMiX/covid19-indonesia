# %% [markdown]
# # Cleaning data dari Scraping Web

# %%
import pandas as pd
import unicodedata
df = pd.read_csv("covid_data_dunia.csv") 
df
# Out:
#     Country,Other   TotalCases NewCases  \
# 0           World  676,101,245  +93,611
# 1             USA  104,453,003      NaN
# 2           India   44,683,250      NaN
# 3          France   39,533,323      NaN
# 4         Germany   37,822,577      NaN
# ..            ...          ...      ...
# 228        Total:   67,755,556     +190
# 229        Total:   13,905,992      NaN
# 230        Total:   12,778,769     +176
# 231        Total:          721      NaN
# 232        Total:  676,101,245  +93,611
#
#                                    TotalDeaths  NewDeaths TotalRecovered  \
# 0                                    6,770,476      516.0    648,428,772
# 1    1,135,957                                        NaN    101,520,517
# 2      530,745                                        NaN     44,150,713
# 3      164,286                                        NaN     39,283,319
# 4      166,128                                        NaN     37,427,600
# ..                                         ...        ...            ...
# 228                                  1,347,947       73.0     65,877,684
# 229                                     25,446        NaN     13,743,749
# 230                                    258,523        NaN     12,063,631
# 231                                         15        NaN            706
# 232                                  6,770,476      516.0    648,428,772
#
#     NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  ...  \
# 0       +136,839  20,901,997           41,698           86,737  ...
# 1            NaN   1,796,529            3,354          311,981  ...
# 2            NaN       1,792              698           31,766  ...
# 3         +5,429      85,718              869          602,784  ...
# 4         +3,600     228,849            1,281          450,894  ...
# ..           ...         ...              ...              ...  ...
# 228       +3,782     529,925           10,227              NaN  ...
# 229          NaN     136,797               78              NaN  ...
# 230          NaN     456,615              547              NaN  ...
# 231          NaN           0                0              NaN  ...
# 232     +136,839  20,901,997           41,698         86,737.5  ...
#
#         TotalTests Tests/1M pop      Population          Continent  \
# 0              NaN          NaN             NaN                All
# 1    1,160,733,449    3,466,891    334,805,269       North America
# 2      915,265,788      650,679  1,406,631,776                Asia
# 3      271,490,188    4,139,547     65,584,518              Europe
# 4      122,332,384    1,458,359     83,883,596              Europe
# ..             ...          ...             ...                ...
# 228            NaN          NaN             NaN      South America
# 229            NaN          NaN             NaN  Australia/Oceania
# 230            NaN          NaN             NaN             Africa
# 231            NaN          NaN             NaN                NaN
# 232            NaN          NaN             NaN                All
#
#     1 Caseevery X ppl 1 Deathevery X ppl 1 Testevery X ppl  New Cases/1M pop  \
# 0                  \n                NaN               NaN               NaN
# 1                   3                295               0.0               NaN
# 2                  31              2,650               2.0               NaN
# 3                   2                399               0.0               NaN
# 4                   2                505               1.0               NaN
# ..                ...                ...               ...               ...
# 228                                  NaN               NaN               NaN
# 229                                  NaN               NaN               NaN
# 230                                  NaN               NaN               NaN
# 231                                  NaN               NaN               NaN
# 232                \n                NaN               NaN               NaN
#
#      New Deaths/1M pop  Active Cases/1M pop
# 0                  NaN                  NaN
# 1                  NaN                5,366
# 2                  NaN                    1
# 3                  NaN                1,307
# 4                  NaN                2,728
# ..                 ...                  ...
# 228                NaN                  NaN
# 229                NaN                  NaN
# 230                NaN                  NaN
# 231                NaN                  NaN
# 232                NaN                  NaN
#
# [233 rows x 21 columns]

# %%
df.columns = df.columns.str.replace('\u00A0', ' ') #Menghapus karakter unik di Tot Cases/1M pop
df.drop(columns=['Tot Cases/1M pop','NewCases', 
         'NewDeaths','NewRecovered','Serious,Critical',
         'Deaths/1M pop','TotalTests',
         'Tests/1M pop','Population','Continent',
         '1 Caseevery X ppl','1 Deathevery X ppl','1 Testevery X ppl',
         'New Cases/1M pop','New Deaths/1M pop','Active Cases/1M pop'], inplace=True) #Drop kolom
df
# Out:
#     Country,Other   TotalCases                                TotalDeaths  \
# 0           World  676,101,245                                  6,770,476
# 1             USA  104,453,003  1,135,957
# 2           India   44,683,250    530,745
# 3          France   39,533,323    164,286
# 4         Germany   37,822,577    166,128
# ..            ...          ...                                        ...
# 228        Total:   67,755,556                                  1,347,947
# 229        Total:   13,905,992                                     25,446
# 230        Total:   12,778,769                                    258,523
# 231        Total:          721                                         15
# 232        Total:  676,101,245                                  6,770,476
#
#     TotalRecovered ActiveCases
# 0      648,428,772  20,901,997
# 1      101,520,517   1,796,529
# 2       44,150,713       1,792
# 3       39,283,319      85,718
# 4       37,427,600     228,849
# ..             ...         ...
# 228     65,877,684     529,925
# 229     13,743,749     136,797
# 230     12,063,631     456,615
# 231            706           0
# 232    648,428,772  20,901,997
#
# [233 rows x 5 columns]

# %%
df.tail(15)
# Out:
#              Country,Other   TotalCases  \
# 218                  Macao        3,497
# 219  Saint Pierre Miquelon        3,452
# 220      Wallis and Futuna        3,427
# 221                 Tuvalu        2,805
# 222             MS Zaandam            9
# 223                Tokelau            5
# 224                  China      503,302
# 225                 Total:  123,620,045
# 226                 Total:  213,075,186
# 227                 Total:  244,964,976
# 228                 Total:   67,755,556
# 229                 Total:   13,905,992
# 230                 Total:   12,778,769
# 231                 Total:          721
# 232                 Total:  676,101,245
#
#                                TotalDeaths TotalRecovered ActiveCases
# 218    121                                          3,357          19
# 219      2                                          2,449       1,001
# 220      7                                            438       2,982
# 221                                                   NaN       2,805
# 222      2                                              7           0
# 223                                                   NaN           5
# 224  5,272                                        379,053     118,977
# 225                              1,600,048    118,524,511   3,495,486
# 226                              1,530,766    197,551,660  13,992,760
# 227                              2,007,731    240,666,831   2,290,414
# 228                              1,347,947     65,877,684     529,925
# 229                                 25,446     13,743,749     136,797
# 230                                258,523     12,063,631     456,615
# 231                                     15            706           0
# 232                              6,770,476    648,428,772  20,901,997

# %%
#Menghapus Data Total yang tidak dibutuhkan
index_list = [225, 226, 227, 228, 229, 230, 231, 232]
df = df.drop(index_list)
df.tail(10)
# Out:
#              Country,Other TotalCases                            TotalDeaths  \
# 215               Kiribati      5,008     18
# 216                  Nauru      4,621      1
# 217               Anguilla      3,904     12
# 218                  Macao      3,497    121
# 219  Saint Pierre Miquelon      3,452      2
# 220      Wallis and Futuna      3,427      7
# 221                 Tuvalu      2,805
# 222             MS Zaandam          9      2
# 223                Tokelau          5
# 224                  China    503,302  5,272
#
#     TotalRecovered ActiveCases
# 215          2,703       2,287
# 216          4,609          11
# 217          3,879          13
# 218          3,357          19
# 219          2,449       1,001
# 220            438       2,982
# 221            NaN       2,805
# 222              7           0
# 223            NaN           5
# 224        379,053     118,977

# %%
#Merubah data NaN menjadi 0
df.index = df.index.fillna(0)
df = df.fillna(0)
df.tail()
# Out:
#          Country,Other TotalCases                            TotalDeaths  \
# 220  Wallis and Futuna      3,427      7
# 221             Tuvalu      2,805
# 222         MS Zaandam          9      2
# 223            Tokelau          5
# 224              China    503,302  5,272
#
#     TotalRecovered ActiveCases
# 220            438       2,982
# 221              0       2,805
# 222              7           0
# 223              0           5
# 224        379,053     118,977

# %%
#jadikan file CSV
df.to_csv('covid_data_dunia_cleaned.csv', index=False)
